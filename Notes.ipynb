# %% [markdown]
# ### Next Data Run Updates

# %% [markdown]
# - Update parameters to suggested values from literature if found
# - record dataset reduction post network fitltering
# - reduction plot needs traj not tripleg
# - quantatatve difference factor
